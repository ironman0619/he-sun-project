# %%
import pandas as pd
import os

def process_tennis_data(year):
    """
    Processes and cleans the tennis match data for a specified year.

    Parameters:
    year (int): The year of the tennis data to be processed.

    Returns:
    pd.DataFrame: The cleaned DataFrame containing tennis match data for the specified year.
    """
    file_path = f'{year}.csv'

    # Attempt to read the CSV file using different encodings
    try:
        df = pd.read_csv(file_path, encoding='latin1', on_bad_lines='skip')
    except UnicodeDecodeError:
        df = pd.read_csv(file_path, encoding='utf-8', on_bad_lines='skip')

    # Rename the first column to "ATP"
    df.columns.values[0] = 'ATP'

    # Remove rows with too many missing values
    df_cleaned = df.dropna(thresh=15)

    # Select only the columns of interest
    columns_of_interest = ['ATP', 'Location', 'Tournament', 'Date', 'Series', 'Court', 'Surface', 'Round', 'Best of',
                           'Winner', 'Loser', 'WRank', 'LRank', 'Wsets', 'Lsets', 'Comment', 'PSW', 'PSL', 'B365W', 'B365L']
    df_cleaned = df_cleaned[columns_of_interest]

    # Convert the 'Date' column to datetime format
    df_cleaned['Date'] = pd.to_datetime(df_cleaned['Date'], dayfirst=True, errors='coerce')

    # Convert rank and sets columns to numeric format, handling errors by coercion
    numeric_columns = ['WRank', 'LRank', 'Wsets', 'Lsets']
    df_cleaned[numeric_columns] = df_cleaned[numeric_columns].apply(pd.to_numeric, errors='coerce')

    # Handle missing values in 'WRank' and 'LRank' by filling with the median
    df_cleaned['LRank'] = df_cleaned['LRank'].fillna(df_cleaned['LRank'].median())
    df_cleaned['WRank'] = df_cleaned['WRank'].fillna(df_cleaned['WRank'].median())

    # Save the cleaned DataFrame to a new CSV file
    cleaned_file_path = f'cleaned_{year}.csv'
    df_cleaned.to_csv(cleaned_file_path, index=False)

    # Display a summary of the cleaned DataFrame
    print(f'Data summary for the year {year}:')
    print(df_cleaned.describe(include='all'))

    return df_cleaned

def process_multiple_years(start_year, end_year):
    """
    Processes and cleans tennis match data files for a range of years.

    Parameters:
    start_year (int): The starting year of the range.
    end_year (int): The ending year of the range.
    """

    for year in range(start_year, end_year + 1):
        # Check if the file for the given year exists
        if os.path.exists(f'{year}.csv'):
            process_tennis_data(year)
        else:
            print(f'No data file found for the year {year}.')

# Example usage
process_multiple_years(2013, 2023)
# Out:
# Summary for 2013:
#                 ATP Location   Tournament                           Date  \
# count   2631.000000     2631         2631                           2631
# unique          NaN       63           65                            NaN
# top             NaN    Paris  French Open                            NaN
# freq            NaN      174          127                            NaN
# mean      32.797796      NaN          NaN  2013-05-31 17:10:36.259976960
# min        1.000000      NaN          NaN            2012-12-31 00:00:00
# 25%       19.000000      NaN          NaN            2013-03-10 00:00:00
# 50%       32.000000      NaN          NaN            2013-06-01 00:00:00
# 75%       49.000000      NaN          NaN            2013-08-12 00:00:00
# max       65.000000      NaN          NaN            2013-11-11 00:00:00
# std       17.755676      NaN          NaN                            NaN
#
#         Series    Court Surface      Round      Best of    Winner       Loser  \
# count     2631     2631    2631       2631  2631.000000      2631        2631
# unique       5        2       3          8          NaN       199         306
# top     ATP250  Outdoor    Hard  1st Round          NaN  Nadal R.  Andujar P.
# freq      1152     2117    1480       1176          NaN        75          31
# mean       NaN      NaN     NaN        NaN     3.385405       NaN         NaN
# min        NaN      NaN     NaN        NaN     3.000000       NaN         NaN
# 25%        NaN      NaN     NaN        NaN     3.000000       NaN         NaN
# 50%        NaN      NaN     NaN        NaN     3.000000       NaN         NaN
# 75%        NaN      NaN     NaN        NaN     3.000000       NaN         NaN
# max        NaN      NaN     NaN        NaN     5.000000       NaN         NaN
# std        NaN      NaN     NaN        NaN     0.788993       NaN         NaN
#
#               WRank        LRank        Wsets        Lsets    Comment  \
# count   2631.000000  2631.000000  2614.000000  2614.000000       2631
# unique          NaN          NaN          NaN          NaN          3
# top             NaN          NaN          NaN          NaN  Completed
# freq            NaN          NaN          NaN          NaN       2521
# mean      53.264158    85.759027     2.144989     0.413925        NaN
# min        1.000000     1.000000     0.000000     0.000000        NaN
# 25%       15.000000    32.000000     2.000000     0.000000        NaN
# 50%       38.000000    61.000000     2.000000     0.000000        NaN
# 75%       72.000000    97.000000     2.000000     1.000000        NaN
# max      920.000000  1855.000000     3.000000     2.000000        NaN
# std       64.085190   112.157506     0.468711     0.562964        NaN
#
#                 PSW          PSL        B365W        B365L
# count   2616.000000  2616.000000  2628.000000  2628.000000
# unique          NaN          NaN          NaN          NaN
# top             NaN          NaN          NaN          NaN
# freq            NaN          NaN          NaN          NaN
# mean       1.944163     4.450986     1.857893     4.172425
# min        1.010000     1.010000     1.000000     1.002000
# 25%        1.247500     1.790000     1.200000     1.660000
# 50%        1.520000     2.730000     1.440000     2.620000
# 75%        2.140000     4.512500     2.100000     4.330000
# max       46.000000    81.000000    29.000000    51.000000
# std        1.708719     5.634520     1.438880     4.815769
# Summary for 2014:
#                 ATP Location   Tournament                           Date  \
# count   2600.000000     2600         2600                           2600
# unique          NaN       62           64                            NaN
# top             NaN    Paris  French Open                            NaN
# freq            NaN      174          127                            NaN
# mean      32.403077      NaN          NaN  2014-05-29 09:51:30.461538304
# min        1.000000      NaN          NaN            2013-12-30 00:00:00
# 25%       19.000000      NaN          NaN            2014-03-08 00:00:00
# 50%       32.000000      NaN          NaN            2014-05-29 00:00:00
# 75%       48.000000      NaN          NaN            2014-08-06 00:00:00
# max       64.000000      NaN          NaN            2014-11-16 00:00:00
# std       17.514613      NaN          NaN                            NaN
#
#         Series    Court Surface      Round      Best of      Winner     Loser  \
# count     2600     2600    2600       2600  2600.000000        2600      2600
# unique       5        2       3          8          NaN         197       291
# top     ATP250  Outdoor    Hard  1st Round          NaN  Federer R.  Sousa J.
# freq      1121     2175    1449       1160          NaN          68        34
# mean       NaN      NaN     NaN        NaN     3.390000         NaN       NaN
# min        NaN      NaN     NaN        NaN     3.000000         NaN       NaN
# 25%        NaN      NaN     NaN        NaN     3.000000         NaN       NaN
# 50%        NaN      NaN     NaN        NaN     3.000000         NaN       NaN
# 75%        NaN      NaN     NaN        NaN     3.000000         NaN       NaN
# max        NaN      NaN     NaN        NaN     5.000000         NaN       NaN
# std        NaN      NaN     NaN        NaN     0.792554         NaN       NaN
#
#               WRank        LRank        Wsets        Lsets    Comment  \
# count   2600.000000  2600.000000  2575.000000  2575.000000       2600
# unique          NaN          NaN          NaN          NaN          3
# top             NaN          NaN          NaN          NaN  Completed
# freq            NaN          NaN          NaN          NaN       2488
# mean      54.504615    85.512692     2.147961     0.408155        NaN
# min        1.000000     1.000000     0.000000     0.000000        NaN
# 25%       15.000000    34.000000     2.000000     0.000000        NaN
# 50%       40.000000    62.500000     2.000000     0.000000        NaN
# 75%       73.000000   101.000000     2.000000     1.000000        NaN
# max      847.000000  2159.000000     3.000000     2.000000        NaN
# std       64.308612   105.221943     0.470838     0.554710        NaN
#
#                 PSW          PSL        B365W        B365L
# count   2583.000000  2583.000000  2587.000000  2590.000000
# unique          NaN          NaN          NaN          NaN
# top             NaN          NaN          NaN          NaN
# freq            NaN          NaN          NaN          NaN
# mean       1.906500     4.097456     1.822446     3.865668
# min        1.010000     1.040000     1.000000     1.040000
# 25%        1.260000     1.810000     1.220000     1.720000
# 50%        1.530000     2.710000     1.440000     2.620000
# 75%        2.100000     4.380000     2.000000     4.000000
# max       15.000000    76.000000    13.000000    51.000000
# std        1.177622     4.768089     1.087634     4.270733
# Summary for 2015:
#                 ATP Location   Tournament                           Date  \
# count   2630.000000     2630         2630                           2630
# unique          NaN       64           66                            NaN
# top             NaN    Paris  French Open                            NaN
# freq            NaN      174          127                            NaN
# mean      33.344867      NaN          NaN  2015-06-02 06:43:31.711026688
# min        1.000000      NaN          NaN            2015-01-05 00:00:00
# 25%       19.000000      NaN          NaN            2015-03-15 00:00:00
# 50%       33.000000      NaN          NaN            2015-05-28 00:00:00
# 75%       50.000000      NaN          NaN            2015-08-16 18:00:00
# max       66.000000      NaN          NaN            2015-11-22 00:00:00
# std       18.146295      NaN          NaN                            NaN
#
#         Series    Court Surface      Round      Best of       Winner  \
# count     2630     2630    2630       2630  2630.000000         2630
# unique       5        2       3          8          NaN          192
# top     ATP250  Outdoor    Hard  1st Round          NaN  Djokovic N.
# freq      1062     2178    1476       1176          NaN           82
# mean       NaN      NaN     NaN        NaN     3.385551          NaN
# min        NaN      NaN     NaN        NaN     3.000000          NaN
# 25%        NaN      NaN     NaN        NaN     3.000000          NaN
# 50%        NaN      NaN     NaN        NaN     3.000000          NaN
# 75%        NaN      NaN     NaN        NaN     3.000000          NaN
# max        NaN      NaN     NaN        NaN     5.000000          NaN
# std        NaN      NaN     NaN        NaN     0.789107          NaN
#
#                Loser        WRank        LRank        Wsets        Lsets  \
# count           2630  2630.000000  2630.000000  2621.000000  2621.000000
# unique           284          NaN          NaN          NaN          NaN
# top     Mannarino A.          NaN          NaN          NaN          NaN
# freq              30          NaN          NaN          NaN          NaN
# mean             NaN    51.789354    84.670722     2.144983     0.430752
# min              NaN     1.000000     1.000000     0.000000     0.000000
# 25%              NaN    14.000000    32.000000     2.000000     0.000000
# 50%              NaN    36.000000    60.000000     2.000000     0.000000
# 75%              NaN    66.000000    97.000000     2.000000     1.000000
# max              NaN  1184.000000  1410.000000     3.000000     2.000000
# std              NaN    70.240908   103.977788     0.470872     0.567128
#
#           Comment          PSW          PSL        B365W        B365L
# count        2630  2624.000000  2624.000000  2624.000000  2625.000000
# unique          3          NaN          NaN          NaN          NaN
# top     Completed          NaN          NaN          NaN          NaN
# freq         2528          NaN          NaN          NaN          NaN
# mean          NaN     1.895743     4.268129     1.807234     3.969992
# min           NaN     1.000000     1.020000     1.000000     1.020000
# 25%           NaN     1.250000     1.810000     1.220000     1.720000
# 50%           NaN     1.530000     2.720000     1.440000     2.620000
# 75%           NaN     2.100000     4.460000     2.000000     4.330000
# max           NaN    23.500000    51.000000    17.000000   101.000000
# std           NaN     1.325857     4.895381     1.140651     4.728244
# Summary for 2016:
#                 ATP Location Tournament                           Date  \
# count   2626.000000     2626       2626                           2626
# unique          NaN       64         66                            NaN
# top             NaN    Paris  Wimbledon                            NaN
# freq            NaN      174        127                            NaN
# mean      33.293602      NaN        NaN  2016-05-30 13:26:38.476770560
# min        1.000000      NaN        NaN            2016-01-04 00:00:00
# 25%       19.000000      NaN        NaN            2016-03-13 00:00:00
# 50%       33.000000      NaN        NaN            2016-05-26 00:00:00
# 75%       50.000000      NaN        NaN            2016-08-15 00:00:00
# max       66.000000      NaN        NaN            2016-11-20 00:00:00
# std       18.129698      NaN        NaN                            NaN
#
#         Series    Court Surface      Round      Best of     Winner     Loser  \
# count     2626     2626    2626       2626  2626.000000       2626      2626
# unique       5        2       3          8          NaN        212       304
# top     ATP250  Outdoor    Hard  1st Round          NaN  Murray A.  Sousa J.
# freq      1054     2201    1503       1172          NaN         71        32
# mean       NaN      NaN     NaN        NaN     3.386139        NaN       NaN
# min        NaN      NaN     NaN        NaN     3.000000        NaN       NaN
# 25%        NaN      NaN     NaN        NaN     3.000000        NaN       NaN
# 50%        NaN      NaN     NaN        NaN     3.000000        NaN       NaN
# 75%        NaN      NaN     NaN        NaN     3.000000        NaN       NaN
# max        NaN      NaN     NaN        NaN     5.000000        NaN       NaN
# std        NaN      NaN     NaN        NaN     0.789564        NaN       NaN
#
#               WRank        LRank        Wsets        Lsets    Comment  \
# count   2626.000000  2626.000000  2606.000000  2606.000000       2626
# unique          NaN          NaN          NaN          NaN          3
# top             NaN          NaN          NaN          NaN  Completed
# freq            NaN          NaN          NaN          NaN       2527
# mean      58.142041    91.399467     2.154259     0.415196        NaN
# min        1.000000     1.000000     0.000000     0.000000        NaN
# 25%       16.000000    33.000000     2.000000     0.000000        NaN
# 50%       38.000000    62.000000     2.000000     0.000000        NaN
# 75%       73.000000   102.750000     2.000000     1.000000        NaN
# max     1045.000000  1809.000000     3.000000     2.000000        NaN
# std       79.297564   119.022421     0.452753     0.561995        NaN
#
#                 PSW          PSL        B365W        B365L
# count   2620.000000  2620.000000  2623.000000  2623.000000
# unique          NaN          NaN          NaN          NaN
# top             NaN          NaN          NaN          NaN
# freq            NaN          NaN          NaN          NaN
# mean       1.958752     4.199813     1.860923     3.821109
# min        1.000000     1.010000     1.000000     1.010000
# 25%        1.260000     1.810000     1.220000     1.720000
# 50%        1.520000     2.725000     1.440000     2.620000
# 75%        2.110000     4.382500     2.000000     4.000000
# max       31.300000    81.000000    26.000000    51.000000
# std        1.598410     5.223800     1.374220     4.263202
# Summary for 2017:
#                 ATP Location   Tournament                           Date  \
# count   2633.000000     2633         2633                           2633
# unique          NaN       65           67                            NaN
# top             NaN    Paris  French Open                            NaN
# freq            NaN      174          127                            NaN
# mean      33.779719      NaN          NaN  2017-06-02 15:59:49.061906688
# min        1.000000      NaN          NaN            2017-01-01 00:00:00
# 25%       19.000000      NaN          NaN            2017-03-12 00:00:00
# 50%       33.000000      NaN          NaN            2017-06-01 00:00:00
# 75%       51.000000      NaN          NaN            2017-08-13 00:00:00
# max       67.000000      NaN          NaN            2017-11-19 00:00:00
# std       18.560448      NaN          NaN                            NaN
#
#         Series    Court Surface      Round      Best of    Winner       Loser  \
# count     2633     2633    2633       2633  2633.000000      2633        2633
# unique       5        2       3          8          NaN       215         307
# top     ATP250  Outdoor    Hard  1st Round          NaN  Nadal R.  Lorenzi P.
# freq      1108     2208    1503       1180          NaN        67          32
# mean       NaN      NaN     NaN        NaN     3.385112       NaN         NaN
# min        NaN      NaN     NaN        NaN     3.000000       NaN         NaN
# 25%        NaN      NaN     NaN        NaN     3.000000       NaN         NaN
# 50%        NaN      NaN     NaN        NaN     3.000000       NaN         NaN
# 75%        NaN      NaN     NaN        NaN     3.000000       NaN         NaN
# max        NaN      NaN     NaN        NaN     5.000000       NaN         NaN
# std        NaN      NaN     NaN        NaN     0.788764       NaN         NaN
#
#               WRank        LRank        Wsets        Lsets    Comment  \
# count   2633.000000  2633.000000  2617.000000  2616.000000       2633
# unique          NaN          NaN          NaN          NaN          3
# top             NaN          NaN          NaN          NaN  Completed
# freq            NaN          NaN          NaN          NaN       2530
# mean      61.939992    93.740600     2.146351     0.426988        NaN
# min        1.000000     1.000000     0.000000     0.000000        NaN
# 25%       17.000000    35.000000     2.000000     0.000000        NaN
# 50%       40.000000    62.000000     2.000000     0.000000        NaN
# 75%       77.000000   102.000000     2.000000     1.000000        NaN
# max      993.000000  1360.000000     3.000000     2.000000        NaN
# std       81.225217   118.366702     0.462239     0.555196        NaN
#
#                 PSW          PSL        B365W        B365L
# count   2619.000000  2619.000000  2626.000000  2626.000000
# unique          NaN          NaN          NaN          NaN
# top             NaN          NaN          NaN          NaN
# freq            NaN          NaN          NaN          NaN
# mean       1.982115     3.724326     1.882752     3.426527
# min        1.010000     1.010000     1.002000     1.010000
# 25%        1.270000     1.755000     1.250000     1.660000
# 50%        1.570000     2.560000     1.530000     2.500000
# 75%        2.200000     4.205000     2.100000     4.000000
# max       27.220000    34.050000    23.000000    41.000000
# std        1.459367     3.509295     1.232150     3.134191
# Summary for 2018:
#                 ATP Location Tournament                           Date  \
# count   2637.000000     2637       2637                           2637
# unique          NaN       64         67                            NaN
# top             NaN    Paris  Wimbledon                            NaN
# freq            NaN      174        127                            NaN
# mean      33.760334      NaN        NaN  2018-06-01 14:34:15.972696320
# min        1.000000      NaN        NaN            2017-12-31 00:00:00
# 25%       19.000000      NaN        NaN            2018-03-11 00:00:00
# 50%       33.000000      NaN        NaN            2018-05-31 00:00:00
# 75%       50.000000      NaN        NaN            2018-08-12 00:00:00
# max       67.000000      NaN        NaN            2018-11-18 00:00:00
# std       18.554584      NaN        NaN                            NaN
#
#         Series    Court Surface      Round      Best of     Winner  \
# count     2637     2637    2637       2637  2637.000000       2637
# unique       5        2       3          8          NaN        211
# top     ATP250  Outdoor    Hard  1st Round          NaN  Zverev A.
# freq      1112     2212    1503       1184          NaN         55
# mean       NaN      NaN     NaN        NaN     3.384528        NaN
# min        NaN      NaN     NaN        NaN     3.000000        NaN
# 25%        NaN      NaN     NaN        NaN     3.000000        NaN
# 50%        NaN      NaN     NaN        NaN     3.000000        NaN
# 75%        NaN      NaN     NaN        NaN     3.000000        NaN
# max        NaN      NaN     NaN        NaN     5.000000        NaN
# std        NaN      NaN     NaN        NaN     0.788308        NaN
#
#              Loser        WRank        LRank        Wsets        Lsets  \
# count         2637  2637.000000  2637.000000  2623.000000  2622.000000
# unique         291          NaN          NaN          NaN          NaN
# top     Dzumhur D.          NaN          NaN          NaN          NaN
# freq            30          NaN          NaN          NaN          NaN
# mean           NaN    60.269245    87.675009     2.161647     0.441266
# min            NaN     1.000000     1.000000     0.000000     0.000000
# 25%            NaN    19.000000    35.000000     2.000000     0.000000
# 50%            NaN    46.000000    64.000000     2.000000     0.000000
# 75%            NaN    80.000000   102.000000     2.000000     1.000000
# max            NaN  1821.000000  1821.000000     3.000000     2.000000
# std            NaN    73.188987   113.471455     0.439064     0.562213
#
#           Comment          PSW          PSL        B365W        B365L
# count        2637  2617.000000  2617.000000  2624.000000  2624.000000
# unique          3          NaN          NaN          NaN          NaN
# top     Completed          NaN          NaN          NaN          NaN
# freq         2555          NaN          NaN          NaN          NaN
# mean          NaN     1.926335     3.463091     1.844909     3.195335
# min           NaN     1.010000     1.030000     1.005000     1.030000
# 25%           NaN     1.340000     1.770000     1.300000     1.660000
# 50%           NaN     1.620000     2.460000     1.570000     2.370000
# 75%           NaN     2.190000     3.600000     2.100000     3.400000
# max           NaN    18.030000    33.900000    15.000000    34.000000
# std           NaN     1.065434     3.414277     0.952127     3.035299
# Summary for 2019:
#                 ATP Location   Tournament                           Date  \
# count   2610.000000     2610         2610                           2610
# unique          NaN       63           66                            NaN
# top             NaN    Paris  French Open                            NaN
# freq            NaN      174          127                            NaN
# mean      33.218774      NaN          NaN  2019-05-31 22:04:41.379310336
# min        1.000000      NaN          NaN            2018-12-31 00:00:00
# 25%       19.000000      NaN          NaN            2019-03-09 06:00:00
# 50%       32.000000      NaN          NaN            2019-05-31 00:00:00
# 75%       50.000000      NaN          NaN            2019-08-12 00:00:00
# max       66.000000      NaN          NaN            2019-11-17 00:00:00
# std       18.226778      NaN          NaN                            NaN
#
#         Series    Court Surface      Round      Best of       Winner  \
# count     2610     2610    2610       2610  2610.000000         2610
# unique       5        2       3          8          NaN          204
# top     ATP250  Outdoor    Hard  1st Round          NaN  Medvedev D.
# freq      1085     2185    1503       1172          NaN           58
# mean       NaN      NaN     NaN        NaN     3.388506          NaN
# min        NaN      NaN     NaN        NaN     3.000000          NaN
# 25%        NaN      NaN     NaN        NaN     3.000000          NaN
# 50%        NaN      NaN     NaN        NaN     3.000000          NaN
# 75%        NaN      NaN     NaN        NaN     3.000000          NaN
# max        NaN      NaN     NaN        NaN     5.000000          NaN
# std        NaN      NaN     NaN        NaN     0.791400          NaN
#
#            Loser        WRank        LRank        Wsets        Lsets  \
# count       2610  2610.000000  2610.000000  2589.000000  2589.000000
# unique       291          NaN          NaN          NaN          NaN
# top     Simon G.          NaN          NaN          NaN          NaN
# freq          28          NaN          NaN          NaN          NaN
# mean         NaN    57.110728    77.736782     2.167246     0.431054
# min          NaN     1.000000     1.000000     0.000000     0.000000
# 25%          NaN    19.000000    34.000000     2.000000     0.000000
# 50%          NaN    45.000000    60.000000     2.000000     0.000000
# 75%          NaN    76.000000    95.000000     2.000000     1.000000
# max          NaN   503.000000  1491.000000     3.000000     2.000000
# std          NaN    57.131578    80.086203     0.435385     0.565270
#
#           Comment          PSW          PSL        B365W        B365L
# count        2610  2599.000000  2599.000000  2597.000000  2597.000000
# unique          5          NaN          NaN          NaN          NaN
# top     Completed          NaN          NaN          NaN          NaN
# freq         2530          NaN          NaN          NaN          NaN
# mean          NaN     1.933342     3.474467     1.844926     3.159365
# min           NaN     1.005000     1.070000     1.002000     1.070000
# 25%           NaN     1.330000     1.760000     1.300000     1.660000
# 50%           NaN     1.640000     2.440000     1.570000     2.300000
# 75%           NaN     2.185000     3.625000     2.100000     3.400000
# max           NaN    11.730000    37.800000     9.000000    41.000000
# std           NaN     1.027109     3.597585     0.893305     3.067155
# Summary for 2020:
#                 ATP  Location   Tournament                           Date  \
# count   1267.000000      1267         1267                           1267
# unique          NaN        28           32                            NaN
# top             NaN  New York  French Open                            NaN
# freq            NaN       209          127                            NaN
# mean      16.401736       NaN          NaN  2020-06-19 02:01:36.606156544
# min        1.000000       NaN          NaN            2020-01-06 00:00:00
# 25%        9.000000       NaN          NaN            2020-02-11 00:00:00
# 50%       18.000000       NaN          NaN            2020-09-01 00:00:00
# 75%       22.000000       NaN          NaN            2020-10-02 12:00:00
# max       32.000000       NaN          NaN            2020-11-22 00:00:00
# std        8.745322       NaN          NaN                            NaN
#
#         Series    Court Surface      Round      Best of     Winner  \
# count     1267     1267    1267       1267  1267.000000       1267
# unique       5        2       2          8          NaN        169
# top     ATP250  Outdoor    Hard  1st Round          NaN  Rublev A.
# freq       521      861     889        595          NaN         41
# mean       NaN      NaN     NaN        NaN     3.601421        NaN
# min        NaN      NaN     NaN        NaN     3.000000        NaN
# 25%        NaN      NaN     NaN        NaN     3.000000        NaN
# 50%        NaN      NaN     NaN        NaN     3.000000        NaN
# 75%        NaN      NaN     NaN        NaN     5.000000        NaN
# max        NaN      NaN     NaN        NaN     5.000000        NaN
# std        NaN      NaN     NaN        NaN     0.917496        NaN
#
#                Loser        WRank        LRank        Wsets        Lsets  \
# count           1267  1267.000000  1267.000000  1261.000000  1261.000000
# unique           237          NaN          NaN          NaN          NaN
# top     Mannarino A.          NaN          NaN          NaN          NaN
# freq              17          NaN          NaN          NaN          NaN
# mean             NaN    58.233623    80.917127     2.275971     0.460745
# min              NaN     1.000000     1.000000     0.000000     0.000000
# 25%              NaN    17.000000    34.000000     2.000000     0.000000
# 50%              NaN    42.000000    64.000000     2.000000     0.000000
# 75%              NaN    82.000000   100.000000     3.000000     1.000000
# max              NaN   528.000000   962.000000     3.000000     2.000000
# std              NaN    59.310672    80.960927     0.494383     0.605076
#
#           Comment          PSW          PSL        B365W        B365L
# count        1267  1259.000000  1259.000000  1262.000000  1262.000000
# unique          4          NaN          NaN          NaN          NaN
# top     Completed          NaN          NaN          NaN          NaN
# freq         1237          NaN          NaN          NaN          NaN
# mean          NaN     1.926107     3.896140     1.872632     3.489887
# min           NaN     0.974000     1.030000     0.971000     0.967000
# 25%           NaN     1.300000     1.790000     1.280000     1.720000
# 50%           NaN     1.580000     2.550000     1.530000     2.500000
# 75%           NaN     2.155000     3.910000     2.000000     3.500000
# max           NaN    20.000000    37.070000    34.000000    51.000000
# std           NaN     1.286305     4.449604     1.575504     3.840731
# Summary for 2021:
#                 ATP   Location Tournament                           Date  \
# count   2489.000000       2489       2489                           2489
# unique          NaN         57         60                            NaN
# top             NaN  Melbourne    US Open                            NaN
# freq            NaN        237        127                            NaN
# mean      30.612696        NaN        NaN  2021-06-08 13:15:30.012052992
# min        1.000000        NaN        NaN            2021-01-07 00:00:00
# 25%       16.000000        NaN        NaN            2021-03-26 00:00:00
# 50%       30.000000        NaN        NaN            2021-06-04 00:00:00
# 75%       47.000000        NaN        NaN            2021-08-17 00:00:00
# max       61.000000        NaN        NaN            2021-11-21 00:00:00
# std       17.498836        NaN        NaN                            NaN
#
#         Series    Court Surface      Round      Best of   Winner      Loser  \
# count     2489     2489    2489       2489  2489.000000     2489       2489
# unique       5        2       3          8          NaN      215        307
# top     ATP250  Outdoor    Hard  1st Round          NaN  Ruud C.  Bublik A.
# freq      1160     2029    1448       1094          NaN       53         28
# mean       NaN      NaN     NaN        NaN     3.407393      NaN        NaN
# min        NaN      NaN     NaN        NaN     3.000000      NaN        NaN
# 25%        NaN      NaN     NaN        NaN     3.000000      NaN        NaN
# 50%        NaN      NaN     NaN        NaN     3.000000      NaN        NaN
# 75%        NaN      NaN     NaN        NaN     3.000000      NaN        NaN
# max        NaN      NaN     NaN        NaN     5.000000      NaN        NaN
# std        NaN      NaN     NaN        NaN     0.805653      NaN        NaN
#
#               WRank        LRank        Wsets        Lsets    Comment  \
# count   2489.000000  2489.000000  2469.000000  2468.000000       2489
# unique          NaN          NaN          NaN          NaN          5
# top             NaN          NaN          NaN          NaN  Completed
# freq            NaN          NaN          NaN          NaN       2408
# mean      63.087184    93.189634     2.170919     0.435981        NaN
# min        1.000000     1.000000     0.000000     0.000000        NaN
# 25%       20.000000    37.000000     2.000000     0.000000        NaN
# 50%       47.000000    67.000000     2.000000     0.000000        NaN
# 75%       84.000000   107.000000     2.000000     1.000000        NaN
# max     1165.000000  2146.000000     3.000000     2.000000        NaN
# std       69.587768   120.002657     0.455416     0.573317        NaN
#
#                 PSW          PSL        B365W        B365L
# count   2482.000000  2482.000000  2468.000000  2468.000000
# unique          NaN          NaN          NaN          NaN
# top             NaN          NaN          NaN          NaN
# freq            NaN          NaN          NaN          NaN
# mean       1.931322     3.597220     1.896712     3.303793
# min        1.010000     1.060000     1.000000     0.967000
# 25%        1.320000     1.750000     1.300000     1.720000
# 50%        1.600000     2.490000     1.570000     2.370000
# 75%        2.200000     3.760000     2.100000     3.500000
# max       12.790000    33.670000    29.000000    51.000000
# std        1.062528     3.724521     1.343524     3.221935
# Summary for 2022:
#                 ATP Location       Tournament                           Date  \
# count   2632.000000     2632             2632                           2632
# unique          NaN       65               67                            NaN
# top             NaN    Paris  Australian Open                            NaN
# freq            NaN      182              127                            NaN
# mean      33.829027      NaN              NaN  2022-06-03 03:26:15.683890432
# min        1.000000      NaN              NaN            2022-01-03 00:00:00
# 25%       19.000000      NaN              NaN            2022-03-14 00:00:00
# 50%       32.000000      NaN              NaN            2022-06-01 00:00:00
# 75%       50.000000      NaN              NaN            2022-08-17 00:00:00
# max       68.000000      NaN              NaN            2022-11-20 00:00:00
# std       18.708237      NaN              NaN                            NaN
#
#         Series    Court Surface      Round      Best of        Winner  \
# count     2632     2632    2632       2632  2617.000000          2632
# unique       5        2       3          8          NaN           209
# top     ATP250  Outdoor    Hard  1st Round          NaN  Tsitsipas S.
# freq      1189     2141    1529       1180          NaN            57
# mean       NaN      NaN     NaN        NaN     3.387467           NaN
# min        NaN      NaN     NaN        NaN     3.000000           NaN
# 25%        NaN      NaN     NaN        NaN     3.000000           NaN
# 50%        NaN      NaN     NaN        NaN     3.000000           NaN
# 75%        NaN      NaN     NaN        NaN     3.000000           NaN
# max        NaN      NaN     NaN        NaN     5.000000           NaN
# std        NaN      NaN     NaN        NaN     0.790596           NaN
#
#               Loser        WRank        LRank        Wsets        Lsets  \
# count          2632  2632.000000  2632.000000  2615.000000  2615.000000
# unique          306          NaN          NaN          NaN          NaN
# top     Karatsev A.          NaN          NaN          NaN          NaN
# freq             29          NaN          NaN          NaN          NaN
# mean            NaN    57.719985    85.976824     2.157935     0.437859
# min             NaN     1.000000     1.000000     0.000000     0.000000
# 25%             NaN    17.000000    34.000000     2.000000     0.000000
# 50%             NaN    43.000000    63.000000     2.000000     0.000000
# 75%             NaN    78.250000   104.000000     2.000000     1.000000
# max             NaN   862.000000  1545.000000     3.000000     2.000000
# std             NaN    59.178670    96.923143     0.450186     0.568105
#
#           Comment          PSW          PSL        B365W        B365L
# count        2632  2617.000000  2617.000000  2622.000000  2622.000000
# unique          3          NaN          NaN          NaN          NaN
# top     Completed          NaN          NaN          NaN          NaN
# freq         2547          NaN          NaN          NaN          NaN
# mean          NaN     1.916802     3.523817     1.851135     3.241880
# min           NaN     0.972000     1.040000     1.005000     1.040000
# 25%           NaN     1.310000     1.760000     1.280000     1.720000
# 50%           NaN     1.580000     2.550000     1.530000     2.500000
# 75%           NaN     2.180000     3.840000     2.100000     3.750000
# max           NaN    15.340000    35.590000    13.000000    34.000000
# std           NaN     1.089461     3.400541     0.969379     2.745631
# Summary for 2023:
#                 ATP Location   Tournament                           Date  \
# count   2703.000000     2703         2703                           2703
# unique          NaN       63           64                            NaN
# top             NaN    Paris  French Open                            NaN
# freq            NaN      182          127                            NaN
# mean      32.782094      NaN          NaN  2023-06-05 15:26:58.201997568
# min        1.000000      NaN          NaN            2023-01-01 00:00:00
# 25%       19.000000      NaN          NaN            2023-03-22 00:00:00
# 50%       31.000000      NaN          NaN            2023-06-02 00:00:00
# 75%       49.000000      NaN          NaN            2023-08-16 00:00:00
# max       64.000000      NaN          NaN            2023-11-19 00:00:00
# std       17.710839      NaN          NaN                            NaN
#
#         Series    Court Surface      Round      Best of       Winner  \
# count     2703     2703    2703       2703  2703.000000         2703
# unique       5        2       3          8          NaN          224
# top     ATP250  Outdoor    Hard  1st Round          NaN  Medvedev D.
# freq      1081     2297    1520       1184          NaN           67
# mean       NaN      NaN     NaN        NaN     3.375139          NaN
# min        NaN      NaN     NaN        NaN     3.000000          NaN
# 25%        NaN      NaN     NaN        NaN     3.000000          NaN
# 50%        NaN      NaN     NaN        NaN     3.000000          NaN
# 75%        NaN      NaN     NaN        NaN     3.000000          NaN
# max        NaN      NaN     NaN        NaN     5.000000          NaN
# std        NaN      NaN     NaN        NaN     0.780880          NaN
#
#            Loser        WRank        LRank        Wsets        Lsets  \
# count       2703  2703.000000  2703.000000  2684.000000  2684.000000
# unique       319          NaN          NaN          NaN          NaN
# top     Giron M.          NaN          NaN          NaN          NaN
# freq          29          NaN          NaN          NaN          NaN
# mean         NaN    61.963004   113.371069     2.155738     0.434054
# min          NaN     1.000000     1.000000     0.000000     0.000000
# 25%          NaN    16.500000    35.000000     2.000000     0.000000
# 50%          NaN    46.000000    66.000000     2.000000     0.000000
# 75%          NaN    82.000000   107.000000     2.000000     1.000000
# max          NaN  1035.000000  4915.000000     3.000000     2.000000
# std          NaN    75.793279   222.210867     0.446505     0.565938
#
#           Comment          PSW          PSL        B365W        B365L
# count        2703  2691.000000  2691.000000  2698.000000  2698.000000
# unique          4          NaN          NaN          NaN          NaN
# top     Completed          NaN          NaN          NaN          NaN
# freq         2614          NaN          NaN          NaN          NaN
# mean          NaN     1.919955     3.619796     1.867325     3.353921
# min           NaN     1.010000     1.020000     1.000000     1.010000
# 25%           NaN     1.310000     1.750000     1.300000     1.685000
# 50%           NaN     1.610000     2.470000     1.570000     2.380000
# 75%           NaN     2.190000     3.765000     2.175000     3.500000
# max           NaN    30.500000    64.190000    23.000000    67.000000
# std           NaN     1.109373     4.066680     0.993034     3.410576

# %%
import pandas as pd

# List of cleaned data files from different years
file_paths = [
    'cleaned_2013.csv',
    'cleaned_2014.csv',
    'cleaned_2015.csv',
    'cleaned_2016.csv',
    'cleaned_2017.csv',
    'cleaned_2018.csv',
    'cleaned_2019.csv',
    'cleaned_2020.csv',
    'cleaned_2021.csv',
    'cleaned_2022.csv',
]

# Initialize an empty list to hold dataframes
data_frames = []

# Loop through each file path and read the CSV files into dataframes
for file in file_paths:
    df = pd.read_csv(file)
    data_frames.append(df)

# Concatenate all dataframes into a single dataframe
combined_dataframe = pd.concat(data_frames, ignore_index=True)

# Display the first few rows of the combined dataframe
print(combined_dataframe.head())

# Define the output file path for the combined data
output_file = 'combined_tennis_data_2013_2022.csv'

# Save the combined dataframe to a new CSV file
combined_dataframe.to_csv(output_file, index=False)

# Print confirmation message
print(f'Combined data saved to {output_file}')
# Out:
# 'combined_tennis_data_2013_2022.csv'
